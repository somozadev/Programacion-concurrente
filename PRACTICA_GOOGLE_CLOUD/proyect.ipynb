# %%
import os, io, json, pandas as pd

# %%
from google.cloud import vision

# %%
from IPython import display

# %%
display.Image("pickle.jpg")

# %% [markdown]
# <h1>Crear las credenciales</h1>
#
# <p> ir a mi proyecto </p>
# <p> activar cloud vision</p>
# <p> usar la cuenta de servicio creada via credenciales para entrar </p>
# <p> selecciono la cuenta de servicio</p>
# genero y descargo el json

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'C:/Users/mesom/CARRERA/Programacion-concurrente/practica_google_cloud/practica-pdc-somoza-2245e024fd93.json'

# %%
client = vision.ImageAnnotatorClient()
